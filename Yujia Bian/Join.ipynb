# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
df_sold = pd.read_csv('csv/sold.csv')
df_sold.head()
# Out:
#    BOROUGH                 ADDRESS  ZIP CODE  GROSS SQUARE FEET  YEAR BUILT  \
# 0        2  1667 WASHINGTON AVENUE   10457.0             3167.0      1899.0
# 1        2   410 EAST 179TH STREET   10457.0             2048.0      1901.0
# 2        2        4455 PARK AVENUE   10457.0             1587.0      1899.0
# 3        2     443 EAST 180 STREET   10457.0             2820.0      1952.0
# 4        2     2327 WASHINGTON AVE   10458.0             1260.0      1910.0
#
#    SALE PRICE  SALE DATE   Latitude  Longitude           Clean Address  Match
# 0      980000      44812  40.841270 -73.901313  1667 WASHINGTON AVENUE      0
# 1      655000      44866  40.850353 -73.898824   410 EAST 179TH STREET      0
# 2      520000      44860  40.853630 -73.895963        4455 PARK AVENUE      0
# 3      720000      44615  40.851764 -73.896429     443 EAST 180 STREET      0
# 4      499999      44679  40.855949 -73.892532     2327 WASHINGTON AVE      0

# %%
df_permit = pd.read_csv('csv/permit.csv')
df_permit.head()
# Out:
#   Job Filing Number House No      Street Name    Borough  \
# 0      M00897614-S1     2035         5 AVENUE  MANHATTAN
# 1      M00674105-I1      120      WALL STREET  MANHATTAN
# 2      Q00627195-I1    59-09  ST FELIX AVENUE     QUEENS
# 3      B00526868-I1     3316    TILDEN AVENUE   BROOKLYN
# 4      Q00494176-I1    82-22       261 STREET     QUEENS
#
#      Applicant Business Name        Approved Date          Issued Date  \
# 0        VIK XS SERVICES INC  2023-08-09 00:00:00  2023-08-09 00:00:00
# 1  AMBASSADOR CONSTRUCTION C  2022-02-11 00:00:00  2022-02-14 00:00:00
# 2   VARSITY PLBG AND HTG INC  2022-01-20 00:00:00  2022-11-18 00:00:00
# 3   MIGLIORE RESTORATION INC  2021-07-09 00:00:00  2021-08-10 00:00:00
# 4      DRM CONSTRUCTION CORP  2022-03-01 00:00:00  2022-09-23 00:00:00
#
#    Estimated Job Costs      Owner Name                Address  \
# 0               1000.0    VICTOR BOBER          2035 5 AVENUE
# 1               1000.0    BILL DACUNTO        120 WALL STREET
# ...

# %%
df = df_sold.merge(df_permit, on='Clean Address', how='left')

# %%
df
# Out:
#         BOROUGH                   ADDRESS  ZIP CODE  GROSS SQUARE FEET  \
# 0             2    1667 WASHINGTON AVENUE   10457.0             3167.0
# 1             2     410 EAST 179TH STREET   10457.0             2048.0
# 2             2          4455 PARK AVENUE   10457.0             1587.0
# 3             2       443 EAST 180 STREET   10457.0             2820.0
# 4             2       2327 WASHINGTON AVE   10458.0             1260.0
# ...         ...                       ...       ...                ...
# 346040        1             4560 BROADWAY   10040.0                0.0
# 346041        1       150 HILLSIDE AVENUE   10040.0                0.0
# 346042        1       35 OVERLOOK TERRACE   10033.0                0.0
# 346043        1             4275 BROADWAY   10033.0             1950.0
# 346044        1  524 FT WASHINGTON AVENUE   10033.0            24839.0
#
#         YEAR BUILT  SALE PRICE  SALE DATE   Latitude  Longitude  \
# ...
